# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons

X, y = make_moons(n_samples = 100, noise = 0.15, random_state = 42)

def plot_dataset(X, y, axes) :
    plt.plot(X[:, 0][y == 0], X[:, 1][y == 0], "bs")
    plt.plot(X[:, 0][y == 1], X[:, 1][y == 1], "g^")
    plt.axis(axes)
    plt.grid(True, which = 'both')
    plt.xlabel(r"$x_1$", fontsize = 20)
    plt.ylabel(r"$x_2$", fontsize = 20, rotation = 0)
    
plot_dataset(X, y, [-1.5, 2.5, -1, 1.5])
plt.show()

# %%
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler 
import numpy as np

def plot_dataset(X, y, axes) :
    plt.plot(X[:, 0][y == 0], X[:, 1][y == 0], 'bs')
    plt.plot(X[:, 0][y == 1], X[:, 1][y == 1], "g^")
    plt.axis(axes)
    plt.grid(True, which = 'both')
    plt.xlabel(r"$x_1$", fontsize = 20)
    plt.ylabel(r"$x_2$", fontsize = 20, rotation = 0)
    

def plot_predictions(clf, axes) :
    x0s = np.linspace(axes[0], axes[1], 100)
    x1s = np.linspace(axes[2], axes[3], 100)
    x0, x1 = np.meshgrid(x0s, x1s)
    X = np.c_[x0.ravel(), x1.ravel()]
    y_pred = clf.predict(X).reshape(x0.shape)
    y_decision = clf.decision_function(X).reshape(x0.shape)
    pdct = plt.contourf(x0, x1, y_pred, cmap = plt.cm.brg, alpha = 0.2)
    dcct = plt.contourf(x0, x1, y_decision, cmap = plt.cm.brg, alpha = 0.1)
    plt.colorbar(pdct)

# %%
#1. Gammma = 0.1, C = 0.001

rbf_kernel_svm_clf1 = Pipeline([
    ("scaler", StandardScaler()),
    ("svm_clf", SVC(kernel = "rbf", gamma = 0.1, C = 0.001))
])

rbf_kernel_svm_clf1.fit(X, y)

plot_predictions(rbf_kernel_svm_clf1, [-1.5, 2.5, -1, 1.5])
plot_dataset(X, y, [-1.5, 2.5, -1, 1.5])

plt.show()

# %%
#2. Gammma = 0.1, C = 1000

rbf_kernel_svm_clf2 = Pipeline([
    ("scaler", StandardScaler()),
    ("svm_clf", SVC(kernel = "rbf", gamma = 0.1, C = 1000))
])

rbf_kernel_svm_clf2.fit(X, y)

plot_predictions(rbf_kernel_svm_clf2, [-1.5, 2.5, -1, 1.5])
plot_dataset(X, y, [-1.5, 2.5, -1, 1.5])

plt.show()

# %%
#3. Gammma = 1, C = 0.001

rbf_kernel_svm_clf3 = Pipeline([
    ("scaler", StandardScaler()),
    ("svm_clf", SVC(kernel = "rbf", gamma = 1, C = 0.001))
])

rbf_kernel_svm_clf3.fit(X, y)

plot_predictions(rbf_kernel_svm_clf3, [-1.5, 2.5, -1, 1.5])
plot_dataset(X, y, [-1.5, 2.5, -1, 1.5])

plt.show()

# %%
#4. Gammma = 1, C = 1000

rbf_kernel_svm_clf4 = Pipeline([
    ("scaler", StandardScaler()),
    ("svm_clf", SVC(kernel = "rbf", gamma = 1, C = 1000))
])

rbf_kernel_svm_clf4.fit(X, y)

plot_predictions(rbf_kernel_svm_clf4, [-1.5, 2.5, -1, 1.5])
plot_dataset(X, y, [-1.5, 2.5, -1, 1.5])

plt.show()

# %%
#5. Gammma = 5, C = 0.001

rbf_kernel_svm_clf5 = Pipeline([
    ("scaler", StandardScaler()),
    ("svm_clf", SVC(kernel = "rbf", gamma = 5, C = 0.001))
])

rbf_kernel_svm_clf5.fit(X, y)

plot_predictions(rbf_kernel_svm_clf5, [-1.5, 2.5, -1, 1.5])
plot_dataset(X, y, [-1.5, 2.5, -1, 1.5])

plt.show()

# %%
#6. Gammma = 5, C = 1000

rbf_kernel_svm_clf6 = Pipeline([
    ("scaler", StandardScaler()),
    ("svm_clf", SVC(kernel = "rbf", gamma = 5, C = 1000))
])

rbf_kernel_svm_clf6.fit(X, y)

plot_predictions(rbf_kernel_svm_clf6, [-1.5, 2.5, -1, 1.5])
plot_dataset(X, y, [-1.5, 2.5, -1, 1.5])

plt.show()
